# %%
import tensorflow as tf
import tensorflow_io as tfio
import keras
from tensorflow.keras import layers

from keras import Model
from keras.utils import plot_model
import PIL
from PIL import Image, ImageFilter
import numpy as np
import os
import pathlib
import glob

from models import *
from training_utils import AEMonitor

from tfrecord_utils import _parse_function, parse_tfrecord_fn, parse_tfrecord_fn_yuv, load_dataset, get_dataset

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Color space info, for RGB se yuv to False
yuv = False

if yuv:
    mode = "YCbCr"
else:
    mode = "RGB"

# %%
# Get Dataset
ds = get_dataset('/PATH/TO/TFRECORD/training_data.tfrecord', shuffle=256, batch=4, yuv=False)

# %%
# Checkpoint to produce frames to monitor progress
# Optional
sampled_frames = glob.glob('/PATH/TO/FRAMES/*')
sampled_frames.sort()
sampled_frames = sampled_frames[2500:]
prediction_array = np.zeros([512,512,15])
for i in range(5):
    img = Image.open(sampled_frames[10+i]).convert(mode).resize([512,512])
    prediction_array[:,:,i*3:(i+1)*(3)] = ((np.array(img)/255))#*2)-1

monitor_dir = 'monitoring/monitor_dir'
if not os.path.exists(monitor_dir):
    os.mkdir(monitor_dir)
    
monitor = AEMonitor(np.expand_dims(prediction_array,0), monitor_dir, 60, True)

# %%
# Weight checkpoint
weight_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                                        'model_weights/model_name{epoch:04d}',
                                        monitor="val_loss",
                                        verbose=1,
                                        save_best_only=False,
                                        save_weights_only=True,
                                        mode="auto",
                                        save_freq=256*10,
                                        options=None
                                    )

# %%
# Custom Loss Functions
def custom_loss(y_true, y_pred):
    return keras.losses.mean_squared_error(y_true, y_pred) + keras.losses.categorical_crossentropy(y_true, y_pred)# \
#        + tf.keras.losses.KLDivergence()(y_true, y_pred)

def flood_loss(y_true, y_pred):
    flood = 0.01
    return keras.backend.abs(keras.losses.mean_squared_error(y_true, y_pred) - flood) + flood

def sin_loss(y_true, y_pred):
    mse = keras.losses.mean_squared_error(y_true, y_pred)
    return  mse + keras.backend.sin(mse)

lr = tf.keras.optimizers.schedules.ExponentialDecay(
    0.000002, 500, 0.96, staircase=False, name=None
)

# %%
make_deep_model_4().summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 512, 512, 15 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 8)  3008        image[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, 512, 512, 8)  2097152     conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512, 512, 8)  32          p_re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 8)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 3216        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 256, 256, 16) 1048576     conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 12832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 128, 128, 32) 524288      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   51264       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 64, 64, 64)   262144      conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  204928      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 32, 32, 128)  131072      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 16, 16, 256)  65536       conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 256)  1024        p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 256)    590080      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 8, 8, 256)    16384       conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    295040      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 8, 8, 128)    8192        conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 128)    512         p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     73792       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 8, 8, 64)     4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 64)     256         p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 32)     18464       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 8, 8, 32)     2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 32)     128         p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           8256        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          8320        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128)          512         dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          33024       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256)          1024        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          131584      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512)          2048        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2048)         1050624     batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2048)         8192        dense_7[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 8, 8, 32)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 64)     0           reshape[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    147712      concatenate[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 8, 8, 256)    16384       conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  590080      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 16, 16, 256)  65536       conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 256)  1024        p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 384)  0           batch_normalization_19[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  442496      concatenate_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 16, 16, 128)  32768       conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 128)  512         p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  147584      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 32, 32, 128)  131072      conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 128)  512         p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 192)  0           batch_normalization_21[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   307264      concatenate_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 32, 32, 64)   65536       conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 64)   256         p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   102464      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 64, 64, 64)   262144      conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 96)   0           batch_normalization_23[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  307328      concatenate_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 64, 64, 128)  524288      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 128)  512         p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 128 147584      batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 128, 128, 128 2097152     conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 128, 128 512         p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 144 0           batch_normalization_25[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 230464      concatenate_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 128, 128, 64) 1048576     conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 64) 256         p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 36928       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 256, 256, 64) 4194304     conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 64) 256         p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 32) 51232       batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_20 (PReLU)              (None, 256, 256, 32) 2097152     conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 256, 256, 32) 128         p_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 512, 512, 32) 9248        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_21 (PReLU)              (None, 512, 512, 32) 8388608     conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 512, 512, 32) 128         p_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 32) 50208       batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# p_re_lu_22 (PReLU)              (None, 512, 512, 32) 8388608     conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 512, 512, 32) 128         p_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 16) 12816       batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# p_re_lu_23 (PReLU)              (None, 512, 512, 16) 4194304     conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 512, 512, 16) 64          p_re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 8)  1160        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# p_re_lu_24 (PReLU)              (None, 512, 512, 8)  2097152     conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 512, 512, 8)  32          p_re_lu_24[0][0]
# __________________________________________________________________________________________________
# label (Conv2D)                  (None, 512, 512, 3)  219         batch_normalization_32[0][0]
# ==================================================================================================
# Total params: 44,365,923
# Trainable params: 44,353,347
# Non-trainable params: 12,576
# __________________________________________________________________________________________________

# %%
import random
def scheduler(epoch, lr):
    #return random.random()/100
    return random.choice([0.00002,0.000002,0.0000002])
    
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
opt = keras.optimizers.Adam(learning_rate=0.000001)#, beta_1=0.95, beta_2=0.85)
loss_fn = custom_loss

ae = make_deep_model_4()
ae.compile(opt, loss_fn)

print(ae.summary())

try:
    plot_model(ae, to_file="model4.png")
except:
    print("Could not plot")

ae.load_weights('model_weights/model_name')

print("Fitting Model")
ae.fit(ds, epochs = 1000, callbacks=[monitor,weight_checkpoint], steps_per_epoch=256)
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 512, 512, 15 0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 8)  3008        image[0][0]
# __________________________________________________________________________________________________
# p_re_lu_50 (PReLU)              (None, 512, 512, 8)  2097152     conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 512, 512, 8)  32          p_re_lu_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 256, 256, 8)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 16) 3216        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_51 (PReLU)              (None, 256, 256, 16) 1048576     conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 256, 256, 16) 64          p_re_lu_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 128, 128, 16) 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 32) 12832       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_52 (PReLU)              (None, 128, 128, 32) 524288      conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 128, 128, 32) 128         p_re_lu_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 64, 64, 32)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 64)   51264       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_53 (PReLU)              (None, 64, 64, 64)   262144      conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 64, 64, 64)   256         p_re_lu_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 32, 32, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 128)  204928      max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# p_re_lu_54 (PReLU)              (None, 32, 32, 128)  131072      conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 128)  512         p_re_lu_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 16, 16, 128)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_55 (PReLU)              (None, 16, 16, 256)  65536       conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 256)  1024        p_re_lu_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 256)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 256)    590080      max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# p_re_lu_56 (PReLU)              (None, 8, 8, 256)    16384       conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 256)    1024        p_re_lu_56[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    295040      batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# p_re_lu_57 (PReLU)              (None, 8, 8, 128)    8192        conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 8, 8, 128)    512         p_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 64)     73792       batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# p_re_lu_58 (PReLU)              (None, 8, 8, 64)     4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 8, 8, 64)     256         p_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 32)     18464       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# p_re_lu_59 (PReLU)              (None, 8, 8, 32)     2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 32)     128         p_re_lu_59[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 512)          1049088     flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 512)          2048        dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 256)          131328      batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 256)          1024        dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          32896       batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 128)          512         dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 64)           8256        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 64)           256         dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 128)          8320        batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 128)          512         dense_20[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 256)          33024       batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 256)          1024        dense_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 512)          131584      batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 512)          2048        dense_22[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 2048)         1050624     batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 2048)         8192        dense_23[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 8, 8, 32)     0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 64)     0           reshape_2[0][0]
#                                                                  batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 256)    147712      concatenate_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_60 (PReLU)              (None, 8, 8, 256)    16384       conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 256)    1024        p_re_lu_60[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 16, 16, 256)  590080      batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# p_re_lu_61 (PReLU)              (None, 16, 16, 256)  65536       conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 16, 16, 256)  1024        p_re_lu_61[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 16, 16, 384)  0           batch_normalization_85[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 128)  442496      concatenate_11[0][0]
# __________________________________________________________________________________________________
# p_re_lu_62 (PReLU)              (None, 16, 16, 128)  32768       conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 16, 16, 128)  512         p_re_lu_62[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 32, 32, 128)  147584      batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# p_re_lu_63 (PReLU)              (None, 32, 32, 128)  131072      conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 32, 32, 128)  512         p_re_lu_63[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 192)  0           batch_normalization_87[0][0]
#                                                                  max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 64)   307264      concatenate_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_64 (PReLU)              (None, 32, 32, 64)   65536       conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 32, 32, 64)   256         p_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 64, 64, 64)   102464      batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# p_re_lu_65 (PReLU)              (None, 64, 64, 64)   262144      conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 64, 64, 64)   256         p_re_lu_65[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 96)   0           batch_normalization_89[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 128)  307328      concatenate_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_66 (PReLU)              (None, 64, 64, 128)  524288      conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 64, 64, 128)  512         p_re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 128, 128, 128 147584      batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# p_re_lu_67 (PReLU)              (None, 128, 128, 128 2097152     conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 128, 128, 128 512         p_re_lu_67[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 144 0           batch_normalization_91[0][0]
#                                                                  max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 128, 128, 64) 230464      concatenate_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_68 (PReLU)              (None, 128, 128, 64) 1048576     conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 128, 128, 64) 256         p_re_lu_68[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 256, 256, 64) 36928       batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# p_re_lu_69 (PReLU)              (None, 256, 256, 64) 4194304     conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 256, 256, 64) 256         p_re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 32) 51232       batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# p_re_lu_70 (PReLU)              (None, 256, 256, 32) 2097152     conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 256, 256, 32) 128         p_re_lu_70[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 512, 512, 32) 9248        batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# p_re_lu_71 (PReLU)              (None, 512, 512, 32) 8388608     conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 512, 512, 32) 128         p_re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 512, 512, 32) 50208       batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# p_re_lu_72 (PReLU)              (None, 512, 512, 32) 8388608     conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 512, 512, 32) 128         p_re_lu_72[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 512, 512, 16) 12816       batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# p_re_lu_73 (PReLU)              (None, 512, 512, 16) 4194304     conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 512, 512, 16) 64          p_re_lu_73[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 512, 512, 8)  1160        batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# p_re_lu_74 (PReLU)              (None, 512, 512, 8)  2097152     conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 512, 512, 8)  32          p_re_lu_74[0][0]
# __________________________________________________________________________________________________
# label (Conv2D)                  (None, 512, 512, 3)  219         batch_normalization_98[0][0]
# ==================================================================================================
# Total params: 44,365,923
# Trainable params: 44,353,347
# Non-trainable params: 12,576
# __________________________________________________________________________________________________
# None
# Fitting Model
# Epoch 1/1000
# 256/256 [==============================] - 85s 332ms/step - loss: 0.7614
# Epoch 2/1000
# 256/256 [==============================] - 85s 332ms/step - loss: 0.7266
# Epoch 3/1000
# 256/256 [==============================] - 82s 322ms/step - loss: 0.6397
# Epoch 4/1000
# 256/256 [==============================] - 82s 321ms/step - loss: 0.6463
# Epoch 5/1000
# 186/256 [====================>.........] - ETA: 22s - loss: 0.7279
# Epoch 00005: saving model to model_weights/deep_model_4_road_0005
# 256/256 [==============================] - 83s 322ms/step - loss: 0.7204
# Epoch 6/1000
# 256/256 [==============================] - 82s 321ms/step - loss: 0.6960
# Epoch 7/1000
# 256/256 [==============================] - 85s 332ms/step - loss: 0.7331
# Epoch 8/1000
# 256/256 [==============================] - 85s 332ms/step - loss: 0.7634
# Epoch 9/1000
# 256/256 [==============================] - 84s 330ms/step - loss: 0.7688
# Epoch 10/1000
# 256/256 [==============================] - 84s 329ms/step - loss: 0.7849
# Epoch 11/1000
# 256/256 [==============================] - 84s 329ms/step - loss: 0.8194
# Epoch 12/1000
# 256/256 [==============================] - 84s 327ms/step - loss: 0.7987
# Epoch 13/1000
# 256/256 [==============================] - 85s 331ms/step - loss: 0.7462
# Epoch 14/1000
# 256/256 [==============================] - 82s 322ms/step - loss: 0.8144
# Epoch 15/1000
# 186/256 [====================>.........] - ETA: 22s - loss: 0.7606
# Epoch 00015: saving model to model_weights/deep_model_4_road_0015
# 256/256 [==============================] - 83s 325ms/step - loss: 0.7420
# Epoch 16/1000
# 256/256 [==============================] - 83s 323ms/step - loss: 0.7261
# Epoch 17/1000
# 256/256 [==============================] - 82s 321ms/step - loss: 0.7613
# Epoch 18/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7007
# Epoch 19/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.6467
# Epoch 20/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.6309
# Epoch 21/1000
# 256/256 [==============================] - 79s 307ms/step - loss: 0.6521
# Epoch 22/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7510
# Epoch 23/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.3503
# Epoch 24/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1329
# Epoch 25/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.1247
# Epoch 00025: saving model to model_weights/deep_model_4_road_0025
# 256/256 [==============================] - 80s 311ms/step - loss: 0.1208
# Epoch 26/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1757
# Epoch 27/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7059
# Epoch 28/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7392
# Epoch 29/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6443
# Epoch 30/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.6396
# Epoch 31/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7229
# Epoch 32/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.6894
# Epoch 33/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7313
# Epoch 34/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7579
# Epoch 35/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.7797
# Epoch 00035: saving model to model_weights/deep_model_4_road_0035
# 256/256 [==============================] - 80s 312ms/step - loss: 0.7726
# Epoch 36/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7743
# Epoch 37/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.8172
# Epoch 38/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.8030
# Epoch 39/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7451
# Epoch 40/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.8097
# Epoch 41/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7532
# Epoch 42/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7187
# Epoch 43/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7626
# Epoch 44/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7054
# Epoch 45/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.6522
# Epoch 00045: saving model to model_weights/deep_model_4_road_0045
# 256/256 [==============================] - 80s 312ms/step - loss: 0.6478
# Epoch 46/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6403
# Epoch 47/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6322
# Epoch 48/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7672
# Epoch 49/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.3766
# Epoch 50/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1344
# Epoch 51/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1121
# Epoch 52/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1594
# Epoch 53/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6501
# Epoch 54/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7557
# Epoch 55/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.6676
# Epoch 00055: saving model to model_weights/deep_model_4_road_0055
# 256/256 [==============================] - 80s 311ms/step - loss: 0.6482
# Epoch 56/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6306
# Epoch 57/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7218
# Epoch 58/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6875
# Epoch 59/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7309
# Epoch 60/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7521
# Epoch 61/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7771
# Epoch 62/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7662
# Epoch 63/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.8160
# Epoch 64/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.8041
# Epoch 65/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.7498
# Epoch 00065: saving model to model_weights/deep_model_4_road_0065
# 256/256 [==============================] - 80s 312ms/step - loss: 0.7463
# Epoch 66/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.8085
# Epoch 67/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7577
# Epoch 68/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7171
# Epoch 69/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7578
# Epoch 70/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7178
# Epoch 71/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6473
# Epoch 72/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6506
# Epoch 73/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6146
# Epoch 74/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7705
# Epoch 75/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.4799
# Epoch 00075: saving model to model_weights/deep_model_4_road_0075
# 256/256 [==============================] - 80s 312ms/step - loss: 0.4179
# Epoch 76/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1389
# Epoch 77/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1064
# Epoch 78/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.1486
# Epoch 79/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.5892
# Epoch 80/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7733
# Epoch 81/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6580
# Epoch 82/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.6226
# Epoch 83/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7149
# Epoch 84/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6876
# Epoch 85/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.7315
# Epoch 00085: saving model to model_weights/deep_model_4_road_0085
# 256/256 [==============================] - 80s 313ms/step - loss: 0.7288
# Epoch 86/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7409
# Epoch 87/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7855
# Epoch 88/1000
# 256/256 [==============================] - 82s 320ms/step - loss: 0.7619
# Epoch 89/1000
# 256/256 [==============================] - 83s 324ms/step - loss: 0.8129
# Epoch 90/1000
# 256/256 [==============================] - 82s 322ms/step - loss: 0.8047
# Epoch 91/1000
# 256/256 [==============================] - 83s 323ms/step - loss: 0.7531
# Epoch 92/1000
# 256/256 [==============================] - 81s 315ms/step - loss: 0.8016
# Epoch 93/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7690
# Epoch 94/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7135
# Epoch 95/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.7453
# Epoch 00095: saving model to model_weights/deep_model_4_road_0095
# 256/256 [==============================] - 80s 313ms/step - loss: 0.7512
# Epoch 96/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7271
# Epoch 97/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6503
# Epoch 98/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6498
# Epoch 99/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6083
# Epoch 100/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7710
# Epoch 101/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.4583
# Epoch 102/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1470
# Epoch 103/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.1039
# Epoch 104/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.1364
# Epoch 105/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.4367
# Epoch 00105: saving model to model_weights/deep_model_4_road_0105
# 256/256 [==============================] - 80s 311ms/step - loss: 0.5341
# Epoch 106/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7842
# Epoch 107/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6665
# Epoch 108/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.6201
# Epoch 109/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7015
# Epoch 110/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.6910
# Epoch 111/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7271
# Epoch 112/1000
# 256/256 [==============================] - 79s 309ms/step - loss: 0.7396
# Epoch 113/1000
# 256/256 [==============================] - 79s 310ms/step - loss: 0.7822
# Epoch 114/1000
# 256/256 [==============================] - 79s 308ms/step - loss: 0.7601
# Epoch 115/1000
# 186/256 [====================>.........] - ETA: 21s - loss: 0.8219
# Epoch 00115: saving model to model_weights/deep_model_4_road_0115
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-11-89ff345aa542> in <module>
#      15
#      16 print("Fitting Model")
# ---> 17 ae.fit(ds, epochs = 1000, callbacks=[monitor,weight_checkpoint], steps_per_epoch=256)
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     340       hook = getattr(callback, hook_name)
#     341       if getattr(callback, '_supports_tf_logs', False):
# --> 342         hook(batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1238   def on_train_batch_end(self, batch, logs=None):
#    1239     if self._should_save_on_batch(batch):
# -> 1240       self._save_model(epoch=self._current_epoch, logs=logs)
#    1241
#    1242   def on_epoch_begin(self, epoch, logs=None):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1308             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1309           if self.save_weights_only:
# -> 1310             self.model.save_weights(
#    1311                 filepath, overwrite=True, options=self._options)
#    1312           else:
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in save_weights(self, filepath, overwrite, save_format, options)
#    2099              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    2100             % (optimizer,))
# -> 2101       self._trackable_saver.save(filepath, session=session, options=options)
#    2102       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    2103       checkpoint_management.update_checkpoint_state_internal(
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in save(self, file_prefix, checkpoint_number, session, options)
#    1197
#    1198     file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1199     save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1200         file_prefix_tensor, object_graph_tensor, options)
#    1201     if new_feed_additions:
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1143         or context.executing_eagerly() or ops.inside_function()):
#    1144       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1145       save_op = saver.save(file_prefix, options=options)
#    1146       with ops.device("/cpu:0"):
#    1147         with ops.control_dependencies([save_op]):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/training/saving/functional_saver.py in save(self, file_prefix, options)
#     293       tf_function_save()
#     294     else:
# --> 295       return save_fn()
#     296
#     297   def restore(self, file_prefix, options=None):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/training/saving/functional_saver.py in save_fn()
#     267           # initial read operations should be placed on the SaveableObject's
#     268           # device.
# --> 269           sharded_saves.append(saver.save(shard_prefix, options))
#     270
#     271       with ops.control_dependencies(sharded_saves):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/training/saving/functional_saver.py in save(self, file_prefix, options)
#      76     save_device = options.experimental_io_device or "cpu:0"
#      77     with ops.device(save_device):
# ---> 78       return io_ops.save_v2(file_prefix, tensor_names, tensor_slices, tensors)
#      79
#      80   def restore(self, file_prefix, options=None):
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/ops/gen_io_ops.py in save_v2(prefix, tensor_names, shape_and_slices, tensors, name)
#    1727       pass
#    1728     try:
# -> 1729       return save_v2_eager_fallback(
#    1730           prefix, tensor_names, shape_and_slices, tensors, name=name,
#    1731           ctx=_ctx)
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/ops/gen_io_ops.py in save_v2_eager_fallback(prefix, tensor_names, shape_and_slices, tensors, name, ctx)
#    1748   _inputs_flat = [prefix, tensor_names, shape_and_slices] + list(tensors)
#    1749   _attrs = ("dtypes", _attr_dtypes)
# -> 1750   _result = _execute.execute(b"SaveV2", 0, inputs=_inputs_flat, attrs=_attrs,
#    1751                              ctx=ctx, name=name)
#    1752   _result = None
#
# ~/ML_Playground/environments/test_env/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: model_weights/deep_model_4_road_0115_temp_056b9384bfb44660a394d4941fe03cff/part-00000-of-00001.data-00000-of-00001.tempstate499389358356234605; No space left on device [Op:SaveV2]
